# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

dimensions = 512
model = SentenceTransformer("mixedbread-ai/mxbai-embed-large-v1", truncate_dim=dimensions)


open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer(
    "NovaSearch/stella_en_400M_v5",
    trust_remote_code=True,
    config_kwargs={"use_memory_efficient_attention": False, "unpad_inputs": False},
)

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive_q = model.encode([open_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
OA_normal_positive_d = model.encode(
    ["This article has associated data in a data repository"], normalize_embeddings=True
)

OA_hard_positive_q = model.encode([open_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
OA_hard_positive_d = model.encode(
    [
        "The pantheon+ dataset utilized in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available in [88]. The H(z) measurements are provided by [99]. Data for the cosmic microwave \
                                background (CMB) are obtained from [90] and the baryon acoustic oscillations (BAO) dataset is availed from [89]."
    ],
    normalize_embeddings=True,
)

OA_hard_negative_q = model.encode([open_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
OA_hard_negative_d = model.encode(
    ["The data that support the findings of this article are not openly available"], normalize_embeddings=True
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive_q = model.encode([limited_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
LA_normal_positive_d = model.encode(
    [
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request."
    ],
    normalize_embeddings=True,
)

LA_hard_positive_q = model.encode([limited_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
LA_hard_positive_d = model.encode(
    [
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing, and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request"
    ],
    normalize_embeddings=True,
)

LA_hard_negative_q = model.encode([limited_access_anchor], prompt_name="s2s_query", normalize_embeddings=True)
LA_hard_negative_d = model.encode(["Data will be made available on Zenodo"], normalize_embeddings=True)

OA_NP_similarity = cosine_similarity(OA_normal_positive_q, OA_normal_positive_d)
OA_HP_similarity = cosine_similarity(OA_hard_positive_q, OA_hard_positive_d)
OA_HN_similarity = cosine_similarity(OA_hard_negative_q, OA_hard_negative_d)

LA_NP_similarity = cosine_similarity(LA_normal_positive_q, LA_normal_positive_d)
LA_HP_similarity = cosine_similarity(LA_hard_positive_q, LA_hard_positive_d)
LA_HN_similarity = cosine_similarity(LA_hard_negative_q, LA_hard_negative_d)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][0]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][0]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][0]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][0]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][0]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][0]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("dmlls/all-mpnet-base-v2-negation")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = model.similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = model.similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = model.similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = model.similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = model.similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = model.similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("avsolatorio/GIST-large-Embedding-v0")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from angle_emb import AnglE
from sklearn.metrics.pairwise import cosine_similarity

model = AnglE.from_pretrained("WhereIsAI/UAE-Large-V1", pooling_strategy="cls")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("intfloat/e5-mistral-7b-instruct", device="cpu")

# Key difference from other models: instruction only goes on the query side
# documents/corpus are encoded WITHOUT instruction

task = "Retrieve data availability statements that describe the same condition of data availability"

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive_inst = model.encode(
    [open_access_anchor, "This article has associated data in a data repository"],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

OA_hard_positive_inst = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

OA_hard_negative_inst = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive_inst = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

LA_hard_positive_inst = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

LA_hard_negative_inst = model.encode(
    [limited_access_anchor, "Data will be made available in Zenodo"],
    prompt=f"Instruct: {task}\nQuery: ",
    normalize_embeddings=True,
)

OA_NP_similarity = cosine_similarity([OA_normal_positive_inst[0]], [OA_normal_positive_inst[1]])
OA_HP_similarity = cosine_similarity([OA_hard_positive_inst[0]], [OA_hard_positive_inst[1]])
OA_HN_similarity = cosine_similarity([OA_hard_negative_inst[0]], [OA_hard_negative_inst[1]])

LA_NP_similarity = cosine_similarity([LA_normal_positive_inst[0]], [LA_normal_positive_inst[1]])
LA_HP_similarity = cosine_similarity([LA_hard_positive_inst[0]], [LA_hard_positive_inst[1]])
LA_HN_similarity = cosine_similarity([LA_hard_negative_inst[0]], [LA_hard_negative_inst[1]])

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][0]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][0]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][0]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][0]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][0]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][0]}")

# %%
from FlagEmbedding import FlagModel
from sklearn.metrics.pairwise import cosine_similarity

model = FlagModel("BAAI/bge-base-en-v1.5")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/paraphrase-MiniLM-L12-v2")


open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = model.similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = model.similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = model.similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = model.similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = model.similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = model.similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from InstructorEmbedding import INSTRUCTOR
from sklearn.metrics.pairwise import cosine_similarity

model = INSTRUCTOR("hkunlp/instructor-base")

instruction = "Represent the data availability statement for detecting whether two statements describe equivalent data access conditions:"

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    [[instruction, open_access_anchor], "This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        [instruction, open_access_anchor],
        [
            instruction,
            "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
        ],
    ]
)

OA_hard_negative = model.encode(
    [
        [instruction, open_access_anchor],
        [instruction, "The data that support the findings of this article are not openly available"],
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
        ],
    ]
)

LA_hard_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
        ],
    ]
)

LA_hard_negative = model.encode(
    [[instruction, limited_access_anchor], [instruction, "Data will be made available on Zenodo"]]
)


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from InstructorEmbedding import INSTRUCTOR
from sklearn.metrics.pairwise import cosine_similarity

model = INSTRUCTOR("hkunlp/instructor-base")

instruction = "Represent this sentence based on information about data availability:"

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    [[instruction, open_access_anchor], "This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        [instruction, open_access_anchor],
        [
            instruction,
            "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
        ],
    ]
)

OA_hard_negative = model.encode(
    [
        [instruction, open_access_anchor],
        [instruction, "The data that support the findings of this article are not openly available"],
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
        ],
    ]
)

LA_hard_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
        ],
    ]
)

LA_hard_negative = model.encode(
    [[instruction, limited_access_anchor], [instruction, "Data will be made available on Zenodo"]]
)


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode([open_access_anchor, "This article has associated data in a data repository"])

OA_hard_positive = model.encode(
    [
        open_access_anchor,
        "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
    ]
)

OA_hard_negative = model.encode(
    [open_access_anchor, "The data that support the findings of this article are not openly available"]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        limited_access_anchor,
        "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode([limited_access_anchor, "Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("nomic-ai/nomic-embed-text-v1", trust_remote_code=True)

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    ["classification: " + open_access_anchor, "classification: This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        "classification: " + open_access_anchor,
        "classification: The pantheon+ dataset utilized in this article will be found at https://pantheonplussh0es.github.io/. \
     It is also available in [88]. The H(z) measurements are provided by [99]. Data for the cosmic microwave \
     background (CMB) are obtained from [90] and the baryon acoustic oscillations (BAO) dataset is availed from [89].",
    ],
    normalize_embeddings=True,
)

OA_hard_negative = model.encode(
    [
        "classification: " + open_access_anchor,
        "classification: The data that support the findings of this article are not openly available",
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        "classification: " + limited_access_anchor,
        "classification: The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        "classification: " + limited_access_anchor,
        "classification: The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode(
    ["classification: " + limited_access_anchor, "classification: Data will be made available on Zenodo"]
)


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("intfloat/e5-base-v2")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    ["passage: " + open_access_anchor, "passage: This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        "passage: " + open_access_anchor,
        "passage: The pantheon+ dataset utilized in this article will be found at https://pantheonplussh0es.github.io/. \
     It is also available in [88]. The H(z) measurements are provided by [99]. Data for the cosmic microwave \
     background (CMB) are obtained from [90] and the baryon acoustic oscillations (BAO) dataset is availed from [89].",
    ],
    normalize_embeddings=True,
)

OA_hard_negative = model.encode(
    [
        "passage: " + open_access_anchor,
        "passage: The data that support the findings of this article are not openly available",
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        "passage: " + limited_access_anchor,
        "passage: The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        "passage: " + limited_access_anchor,
        "passage: The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode(["passage: " + limited_access_anchor, "passage: Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("intfloat/e5-base-v2")

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    ["query: " + open_access_anchor, "query: This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        "query: " + open_access_anchor,
        "query: The pantheon+ dataset utilized in this article will be found at https://pantheonplussh0es.github.io/. \
     It is also available in [88]. The H(z) measurements are provided by [99]. Data for the cosmic microwave \
     background (CMB) are obtained from [90] and the baryon acoustic oscillations (BAO) dataset is availed from [89].",
    ],
    normalize_embeddings=True,
)

OA_hard_negative = model.encode(
    [
        "query: " + open_access_anchor,
        "query: The data that support the findings of this article are not openly available",
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        "query: " + limited_access_anchor,
        "query: The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
    ]
)

LA_hard_positive = model.encode(
    [
        "query: " + limited_access_anchor,
        "query: The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
    ]
)

LA_hard_negative = model.encode(["query: " + limited_access_anchor, "query: Data will be made available on Zenodo"])


OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")

# %%
from InstructorEmbedding import INSTRUCTOR
from sklearn.metrics.pairwise import cosine_similarity

model = INSTRUCTOR("hkunlp/instructor-base")

instruction = "Represent this sentence to identify whether data is freely and publicly accessible"

open_access_anchor = "The data that support the findings of this article are openly available"

OA_normal_positive = model.encode(
    [[instruction, open_access_anchor], "This article has associated data in a data repository"]
)

OA_hard_positive = model.encode(
    [
        [instruction, open_access_anchor],
        [
            instruction,
            "The pantheon+  dataset  utilized  in this article will be found at https://pantheonplussh0es.github.io/. \
                                It is also available  in [88]. The 𝐻(𝑧) measurements  are provided  by [99]. Data for the cosmic microwave \
                                background  (CMB) are obtained  from [90] and the baryon acoustic  oscillations  (BAO) dataset  is availed  from [89].",
        ],
    ]
)

OA_hard_negative = model.encode(
    [
        [instruction, open_access_anchor],
        [instruction, "The data that support the findings of this article are not openly available"],
    ]
)

limited_access_anchor = "Data will be made available on reasonable request."

LA_normal_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available. \
                                The data are available from the authors upon reasonable request.",
        ],
    ]
)

LA_hard_positive = model.encode(
    [
        [instruction, limited_access_anchor],
        [
            instruction,
            "The data that support the findings of this article are not publicly available upon publication \
                                because it is not technically feasible and/or the cost of preparing, depositing,and hosting the data \
                                would be prohibitive within the terms of this research project. \
                                The data are available from the authors upon reasonable request",
        ],
    ]
)

LA_hard_negative = model.encode(
    [[instruction, limited_access_anchor], [instruction, "Data will be made available on Zenodo"]]
)

OA_NP_similarity = cosine_similarity(OA_normal_positive, OA_normal_positive)
OA_HP_similarity = cosine_similarity(OA_hard_positive, OA_hard_positive)
OA_HN_similarity = cosine_similarity(OA_hard_negative, OA_hard_negative)

LA_NP_similarity = cosine_similarity(LA_normal_positive, LA_normal_positive)
LA_HP_similarity = cosine_similarity(LA_hard_positive, LA_hard_positive)
LA_HN_similarity = cosine_similarity(LA_hard_negative, LA_hard_negative)

print(f"Normal positive similarity for open access anchor: {OA_NP_similarity[0][1]}")
print(f"Hard positive similarity for open access anchor: {OA_HP_similarity[0][1]}")
print(f"Hard negative similarity for open access anchor: {OA_HN_similarity[0][1]}")

print(f"Normal positive similarity for limited access anchor: {LA_NP_similarity[0][1]}")
print(f"Hard positive similarity for limited access anchor: {LA_HP_similarity[0][1]}")
print(f"Hard negative similarity for limited access anchor: {LA_HN_similarity[0][1]}")
